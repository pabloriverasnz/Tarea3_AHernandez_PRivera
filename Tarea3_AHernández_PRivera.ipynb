# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Andrés Hernández Jiménez, Pablo Alejandro Rivera Sánchez
#
# **Fecha:** 15 de febrero del 2021.
#
# **Expediente** :  717895, 721005.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link repositorio: https://github.com/pabloriverasnz/Tarea3_AHernandez_PRivera**
#
# # Tarea 3: Clase 6

# %% [markdown]
# ## Enunciado de tarea
# > > Usando compresión de listas o funciones map(sino recuerda como funciona observar el siguiente enlace https://www.pythonforbeginners.com/lists/list-comprehensions-in-python/), resolver los siguientes ejercicios:

# %% [markdown]
# ### Ejercicio 1:
# 1. Resolver la siguiente ecuación recursiva usando funciones como se vió en clase
# $$ D_{n}=(n-1) D_{n-1}+(n-1) D_{n-2} \quad n\ge 3$$
# con $D_1=0$ y $D_2 = 1$

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés

# %% [markdown]
# ### Ejercicio 2:
# 2. Cuente el número de espacios en la siguiente cadena `variable = relaciónn requiere, para obtener el valor de un término término, el conocimiento de los dos anteriores`.

# %%
variable =  'relaciónn requiere, para obtener el valor de un término término, el conocimiento de los dos anteriores'
variable
# Out:
# 'relaciónn requiere, para obtener el valor de un término término, el conocimiento de los dos anteriores'

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés

# %% [markdown]
# ### Ejercicio 3:
# 3. Remove all of the vowels in a string [make a list of the non-vowels].

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés

# %% [markdown]
# ### Ejercicio 4:
# 4. Find all of the words in a string that are less than 4 letters.

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés

# %% [markdown]
# ### Ejercicio 5:
# 5. Use a dictionary comprehension to count the length of each word in a sentence.

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés

# %% [markdown]
# ### Ejercicio 6:
# 6. Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9).

# %%
# Respuesta Pablo

# %%
# Respuesta Andrés
